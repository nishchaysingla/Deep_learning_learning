# %% [markdown]
# <a href="https://colab.research.google.com/github/nishchaysingla/Deep_learning_learning/blob/main/Video_59_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Video 59 Notes**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Demonstration of Forward Pass in RNN in above image
## Default activation function is tanh in RNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Clculating derivative is very complex as number of words keep on increasing
## In short It can be represented by summation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## For calculating derivative wrt hidden layer , Formula is shown above
